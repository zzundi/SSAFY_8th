# %%
gear = [list(map(int, input())) for _ in range(4)]
k = int(input())
for i in range(k):
    gear_n, direct = input().split()
    gear1_2 = gear[0][2] == gear[1][6]
    gear2_3 = gear[1][2] == gear[2][6]
    gear3_4 = gear[2][2] == gear[3][6]       

    if direct == '1':
        
        if gear_n == '1':
            g = gear[0].pop()
            gear[0].insert(0, g)
            if gear1_2 == False:
                g = gear[1].pop(0)
                gear[1].append(g)
                if gear2_3 == False:
                    g = gear[2].pop()
                    gear[2].insert(0, g)
                    if gear3_4 == False:
                        g = gear[3].pop(0)
                        gear[3].append(g)
        elif gear_n == '2':
            g = gear[1].pop()
            gear[1].insert(0, g)
            if gear1_2 == False:
                g = gear[0].pop(0)
                gear[0].append(g)
            if gear2_3 == False:
                g = gear[2].pop(0)
                gear[2].append(g)
                if gear3_4 == False:
                    g = gear[3].pop()
                    gear[3].insert(0, g)
        elif gear_n == '3':
            g = gear[2].pop()
            gear[2].insert(0, g)
            if gear3_4 == False:
                g = gear[3].pop(0)
                gear[3].append(g)
            if gear2_3 == False:
                g = gear[1].pop(0)
                gear[1].append(g)
                if gear1_2 == False:
                    g = gear[0].pop()
                    gear[0].insert(0, g)
        else:
            g = gear[3].pop()
            gear[3].insert(0, g)
            if gear3_4 == False:
                g = gear[2].pop(0)
                gear[2].append(g)
                if gear2_3 == False:
                    g = gear[1].pop()
                    gear[1].insert(0, g)
                    if gear1_2 == False:
                        g = gear[0].pop(0)
                        gear[0].append(g)
    else:
        if gear_n == '1':
            g = gear[0].pop(0)
            gear[0].append(g)
            if gear1_2 == False:
                g = gear[1].pop()
                gear[1].insert(0, g)
                if gear2_3 == False:
                    g = gear[2].pop(0)
                    gear[2].append(g)
                    if gear3_4 == False:
                        g = gear[3].pop()
                        gear[3].insert(0, g)
        elif gear_n == '2':
            g = gear[1].pop(0)
            gear[1].append(g)
            if gear1_2 == False:
                g = gear[0].pop()
                gear[0].insert(0, g)
            if gear2_3 == False:
                g = gear[2].pop()
                gear[2].insert(0, g)
                if gear3_4 == False:
                    g = gear[3].pop(0)
                    gear[3].append(g)
        elif gear_n == '3':
            g = gear[2].pop(0)
            gear[2].append(g)
            if gear3_4 == False:
                g = gear[3].pop()
                gear[3].insert(0, g)
            if gear2_3 == False:
                g = gear[1].pop()
                gear[1].insert(0, g)
                if gear1_2 == False:
                    g = gear[0].pop(0)
                    gear[0].append(g)
        else:
            g = gear[3].pop(0)
            gear[3].append(g)
            if gear3_4 == False:
                g = gear[2].pop()
                gear[2].insert(0, g)
                if gear2_3 == False:
                    g = gear[1].pop(0)
                    gear[1].append(g)
                    if gear1_2 == False:
                        g = gear[0].pop()
                        gear[0].insert(0, g)
    #print(f'{i}: {gear}')
print(str(gear[0][0] + gear[1][0] * 2 + gear[2][0] * 4 + gear[3][0] * 8))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2972/3879270466.py in <module>
#      56                     if gear1_2 == False:
#      57                         g = gear[0].pop(0)
# ---> 58                         gear[0].append(0, g)
#      59     else:
#      60         if gear_n == '1':
#
# TypeError: append() takes exactly one argument (2 given)
